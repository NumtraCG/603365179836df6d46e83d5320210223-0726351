# %% [markdown]
# ***GENERATED CODE FOR 1 PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***TRANSFORMATIONS FUNCTIONS THAT WILL BE APPLIED ON DATA***

# %%
import json
from pyspark.sql.types import IntegerType
from pyspark.ml.feature import StringIndexer
from pyspark.sql.functions import col, when
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import mean, stddev, min, max, col


class CleanseData:
    # def __init__(self,df):
    #     #print()

    def replaceByMean(self, feature, df, mean_=-1):

        meanValue = df.select(mean(col(feature.name)).alias(
            'mean')).collect()[0]["mean"]
        df.fillna(meanValue, subset=[feature.name])
        df.withColumn(feature.name, when(col(feature.name) == " ",
                                         meanValue).otherwise(col(feature.name).cast("Integer")))
        return df

    def replaceByMax(self, feature, df, max_=-1):
        maxValue = df.select(max(col(feature.name)).alias('max')).collect()[
            0]["max"]
        df.fillna(maxValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", maxValue).otherwise(col(feature.name)))
        return df

    def replaceByMin(self, feature, df, min_=-1):
        minValue = df.select(min(col(feature.name)).alias('min')).collect()[
            0]["min"]
        df.fillna(minValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", minValue).otherwise(col(feature.name)))
        return df

    def replaceByStandardDeviation(self, feature, df, stddev_=-1):
        stddevValue = df.select(stddev(col(feature.name)).alias(
            'stddev')).collect()[0]["stddev"]
        df.fillna(stddevValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", stddevValue).otherwise(col(feature.name)))
        return df

    def replaceDateRandomly(self, feature, df):
        fillValue = df.where(col(feature.name).isNotNull()
                             ).head(1)[0][feature.name]
        df.fillna(str(fillValue), subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", fillValue).otherwise(col(feature.name)))
        # print("CleanseData:replaceDateRandomly Schema : ", df.#printSchema())
        return df

    def replaceNullValues(self, fList, df):
        featuresList = df.schema.fields
        for featureObj in fList:
            for feat in featuresList:
                if featureObj["feature"] in feat.name:
                    featureName = feat
                    if "mean" in featureObj["replaceby"]:
                        df = self.replaceByMean(featureName, df)
                    elif "max" in featureObj["replaceby"]:
                        df = self.replaceByMax(featureName, df)
                    elif "min" in featureObj["replaceby"]:
                        df = self.replaceByMin(featureName, df)
                    elif "stddev" in featureObj["replaceby"]:
                        df = self.replaceByStandardDeviation(featureName, df)
                    elif "random" in featureObj["replaceby"]:
                        df = self.replaceDateRandomly(featureName, df)
        return df


def StringIndexerTransform(df, params, transformationData={}):
    dfReturn = df
    feature = params["feature"]

    dfReturn = dfReturn.fillna({feature: ''})
    outcol = feature + "_stringindexer"
    indexer = StringIndexer(
        inputCol=feature, outputCol=outcol, handleInvalid="skip")
    indexed = indexer.fit(dfReturn).transform(dfReturn)
    dfReturn = indexed
    distinct_values_list = dfReturn.select(
        outcol).distinct().rdd.map(lambda r: r[0]).collect()
    len_distinct_values_list = len(distinct_values_list)
    if len_distinct_values_list <= 4:
        changed_type_df = dfReturn.withColumn(
            outcol, dfReturn[outcol].cast(IntegerType()))
        return changed_type_df
    return dfReturn


class TransformationMain:
    # TODO: change df argument in run with following
    def run(transformationDF, config):
        configObj = json.loads(config)
        featureData = configObj["FE"]
        transformationDF = CleanseData().replaceNullValues(featureData, transformationDF)
        transformationDF = transformationDF.drop('Id')
        transformationDF = transformationDF.drop('IsDeleted')
        transformationDF = transformationDF.drop('CreatedById')
        transformationDF = transformationDF.drop('UpdatedById')
        transformationDF = transformationDF.drop('CreatedOn')
        transformationDF = transformationDF.drop('UpdatedOn')
        transformationDF = transformationDF.drop('TenantId')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'AddressLine1', 'transformation_label': 'String Indexer'}], 'feature': 'AddressLine1', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '5658.6', 'stddev': '4782.78', 'min': '1 LONGFELLOW PL', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'AddressLine1'}, {'feature_label': 'AddressLine1', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('AddressLine1')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'AddressLine2', 'transformation_label': 'String Indexer'}], 'feature': 'AddressLine2', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '544.85', 'stddev': '1192.66', 'min': '#1034', 'max': '\xa0', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'AddressLine2'}, {'feature_label': 'AddressLine2', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('AddressLine2')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'City', 'transformation_label': 'String Indexer'}], 'feature': 'City', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'ALBUQUERQUE', 'max': 'zxc', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'City'}, {'feature_label': 'City', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('City')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'State', 'transformation_label': 'String Indexer'}], 'feature': 'State', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'AB', 'max': 'texas', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'State'}, {'feature_label': 'State', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('State')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Zip', 'transformation_label': 'String Indexer'}], 'feature': 'Zip', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '60471.89', 'stddev': '35273.73', 'min': '0', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Zip'}, {'feature_label': 'Zip', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Zip')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'CountryName', 'transformation_label': 'String Indexer'}], 'feature': 'CountryName', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'Canada', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'CountryName'}, {'feature_label': 'CountryName', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('CountryName')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'CountryCode', 'transformation_label': 'String Indexer'}], 'feature': 'CountryCode', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'CA', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'CountryCode'}, {'feature_label': 'CountryCode', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('CountryCode')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Latitude', 'transformation_label': 'String Indexer'}], 'feature': 'Latitude', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '37.03', 'stddev': '10.29', 'min': '0.00E+00', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Latitude'}, {'feature_label': 'Latitude', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Latitude')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Longitude', 'transformation_label': 'String Indexer'}], 'feature': 'Longitude', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '-96.44', 'stddev': '29.02', 'min': '-104.7429902', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Longitude'}, {'feature_label': 'Longitude', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Longitude')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Degrees', 'transformation_label': 'String Indexer'}], 'feature': 'Degrees', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Degrees'}, {'feature_label': 'Degrees', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Degrees')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Minutes', 'transformation_label': 'String Indexer'}], 'feature': 'Minutes', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Minutes'}, {'feature_label': 'Minutes', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Minutes')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Seconds', 'transformation_label': 'String Indexer'}], 'feature': 'Seconds', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Seconds'}, {'feature_label': 'Seconds', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Seconds')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'VerificationStatus', 'transformation_label': 'String Indexer'}], 'feature': 'VerificationStatus', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'InValid', 'max': 'Valid', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'VerificationStatus'}, {'feature_label': 'VerificationStatus', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('VerificationStatus')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Partition', 'transformation_label': 'String Indexer'}], 'feature': 'Partition', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Partition'}, {'feature_label': 'Partition', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Partition')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'VerificationCount', 'transformation_label': 'String Indexer'}], 'feature': 'VerificationCount', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '330', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'VerificationCount'}, {'feature_label': 'VerificationCount', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('VerificationCount')
        display(transformationDF.limit(2).toPandas())
        return transformationDF

# %% [markdown]
# ***AUTOML FUNCTIONS***

# %%
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import pyspark


def functionClassification(sparkDF, listOfFeatures, label):
    sparkDF.persist(pyspark.StorageLevel.MEMORY_AND_DISK)
    df = (sparkDF.toPandas())
    X = (df.drop(label, axis=1))[listOfFeatures].values
    y = df[label].values
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, random_state=1, test_size=0.1)
    tpotModel = TPOTClassifier(verbosity=3, n_jobs=-1, generations=10, max_time_mins=5,
                               population_size=15)
    tpotModel.fit(X_train, y_train)
    display(" Accuracy of Model : %s" % tpotModel.score(X_test, y_test))
    data = {'model': tpotModel,
            'X_test': X_test,
            'y_test': y_test,
            'label': label,
            'columnNames': listOfFeatures}
    return data

# %% [markdown]
# ***READING DATAFRAME***

# %%
#%run 1Hooks.ipynb
try:
	#sourcePreExecutionHook()

	train = HDFSConnector.fetch(spark, "{'url': '/FileStore/platform/uploadedSourceFiles/1613976857367_Train1.csv', 'file_type': 'Delimeted', 'delimiter': ',', 'is_header': 'Use Header Line', 'FilePath': '/BigLynx/Train1.csv', 'filename': '1613976857367_Train1.csv', 'viewFileName': 'Train1.csv'}")

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRANSFORMING DATAFRAME***

# %%
#%run 1Hooks.ipynb
try:
	#transformationPreExecutionHook()

	autofe = TransformationMain.run(train,json.dumps( {"FE": [{"transformationsData": [{"feature_label": "Id", "transformation_label": "String Indexer"}], "feature": "Id", "type": "string", "selected": "False", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "003E1760-4241-47E6-A4E3-895A39684289", "max": "FFFF2B39-A937-43EE-8729-A083775038F8", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Id"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "IsDeleted", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "False", "stats": {"count": "330", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "IsDeleted"}, {"transformationsData": [{"feature_label": "CreatedById", "transformation_label": "String Indexer"}], "feature": "CreatedById", "type": "string", "selected": "False", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "014719C4-ED4F-4F8B-BA72-A207143C522B", "max": "FFDDA2D1-278D-4EC4-8769-8B5734E44D46", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "CreatedById"}, {"transformationsData": [{"feature_label": "UpdatedById", "transformation_label": "String Indexer"}], "feature": "UpdatedById", "type": "string", "selected": "False", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "UpdatedById"}, {"transformationsData": [{"feature_label": "CreatedOn", "transformation_label": "Extract Date"}], "feature": "CreatedOn", "type": "date", "selected": "False", "replaceby": "random", "stats": {"count": "", "mean": "", "stddev": "", "min": "", "max": "", "missing": "0"}, "transformation": [{"transformation": "Extract Date", "selectedAsDefault": 1}], "updatedLabel": "CreatedOn"}, {"transformationsData": [{"feature_label": "UpdatedOn", "transformation_label": "String Indexer"}], "feature": "UpdatedOn", "type": "string", "selected": "False", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "2021-01-12T17:57:36.000Z", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "UpdatedOn"}, {"transformationsData": [{"feature_label": "TenantId", "transformation_label": "String Indexer"}], "feature": "TenantId", "type": "string", "selected": "False", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "60BF9BD9-23DA-4308-8122-840D6F8692D6", "max": "60BF9BD9-23DA-4308-8122-840D6F8692D6", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "TenantId"}, {"transformationsData": [{"feature_label": "AddressLine1", "transformation_label": "String Indexer"}], "feature": "AddressLine1", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "5658.6", "stddev": "4782.78", "min": "1 LONGFELLOW PL", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "AddressLine1"}, {"transformationsData": [{"feature_label": "AddressLine2", "transformation_label": "String Indexer"}], "feature": "AddressLine2", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "544.85", "stddev": "1192.66", "min": "#1034", "max": "\u00a0", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "AddressLine2"}, {"transformationsData": [{"feature_label": "City", "transformation_label": "String Indexer"}], "feature": "City", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "ALBUQUERQUE", "max": "zxc", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "City"}, {"transformationsData": [{"feature_label": "State", "transformation_label": "String Indexer"}], "feature": "State", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "AB", "max": "texas", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "State"}, {"transformationsData": [{"feature_label": "Zip", "transformation_label": "String Indexer"}], "feature": "Zip", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "60471.89", "stddev": "35273.73", "min": "0", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Zip"}, {"transformationsData": [{"feature_label": "CountryName", "transformation_label": "String Indexer"}], "feature": "CountryName", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "Canada", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "CountryName"}, {"transformationsData": [{"feature_label": "CountryCode", "transformation_label": "String Indexer"}], "feature": "CountryCode", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "CA", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "CountryCode"}, {"transformationsData": [{"feature_label": "Latitude", "transformation_label": "String Indexer"}], "feature": "Latitude", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "37.03", "stddev": "10.29", "min": "0.00E+00", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Latitude"}, {"transformationsData": [{"feature_label": "Longitude", "transformation_label": "String Indexer"}], "feature": "Longitude", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "-96.44", "stddev": "29.02", "min": "-104.7429902", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Longitude"}, {"transformationsData": [{"feature_label": "Degrees", "transformation_label": "String Indexer"}], "feature": "Degrees", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Degrees"}, {"transformationsData": [{"feature_label": "Minutes", "transformation_label": "String Indexer"}], "feature": "Minutes", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Minutes"}, {"transformationsData": [{"feature_label": "Seconds", "transformation_label": "String Indexer"}], "feature": "Seconds", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Seconds"}, {"transformationsData": [{"feature_label": "VerificationStatus", "transformation_label": "String Indexer"}], "feature": "VerificationStatus", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "InValid", "max": "Valid", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "VerificationStatus"}, {"transformationsData": [{"feature_label": "Partition", "transformation_label": "String Indexer"}], "feature": "Partition", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Partition"}, {"transformationsData": [{"feature_label": "VerificationCount", "transformation_label": "String Indexer"}], "feature": "VerificationCount", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "330", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "VerificationCount"}, {"feature": "AddressLine1_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "330", "mean": "130.27", "stddev": "90.03", "min": "0.0", "max": "291.0", "missing": "0"}, "updatedLabel": "AddressLine1_stringindexe..."}, {"feature": "AddressLine2_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "330", "mean": "91.14", "stddev": "77.51", "min": "0.0", "max": "241.0", "missing": "0"}, "updatedLabel": "AddressLine2_stringindexe..."}, {"feature": "City_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "330", "mean": "66.35", "stddev": "62.49", "min": "0.0", "max": "200.0", "missing": "0"}, "updatedLabel": "City_stringindexer_transf..."}, {"feature": "State_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "330", "mean": "8.72", "stddev": "10.8", "min": "0.0", "max": "47.0", "missing": "0"}, "updatedLabel": "State_stringindexer_trans..."}, {"feature": "Zip_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "330", "mean": "104.46", "stddev": "81.53", "min": "0.0", "max": "258.0", "missing": "0"}, "updatedLabel": "Zip_stringindexer_transfo..."}, {"feature": "CountryName_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.05", "stddev": "0.22", "min": "0", "max": "2", "missing": "0"}, "updatedLabel": "CountryName_stringindexer..."}, {"feature": "CountryCode_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.05", "stddev": "0.22", "min": "0", "max": "2", "missing": "0"}, "updatedLabel": "CountryCode_stringindexer..."}, {"feature": "Latitude_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "330", "mean": "56.37", "stddev": "63.57", "min": "0.0", "max": "192.0", "missing": "0"}, "updatedLabel": "Latitude_stringindexer_tr..."}, {"feature": "Longitude_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "330", "mean": "55.82", "stddev": "63.18", "min": "0.0", "max": "191.0", "missing": "0"}, "updatedLabel": "Longitude_stringindexer_t..."}, {"feature": "Degrees_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Degrees_stringindexer_tra..."}, {"feature": "Minutes_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Minutes_stringindexer_tra..."}, {"feature": "Seconds_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Seconds_stringindexer_tra..."}, {"feature": "VerificationStatus_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.05", "stddev": "0.22", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "VerificationStatus_string..."}, {"feature": "Partition_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Partition_stringindexer_t..."}, {"feature": "VerificationCount_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "330", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "VerificationCount_stringi..."}]}))

	#transformationPostExecutionHook(autofe)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRAIN MODEL***

# %%
#%run 1Hooks.ipynb
try:
	#mlPreExecutionHook()

	dataAutoML=functionClassification(autofe, ["AddressLine1_stringindexer", "AddressLine2_stringindexer", "City_stringindexer", "State_stringindexer", "Zip_stringindexer", "CountryName_stringindexer", "CountryCode_stringindexer", "Latitude_stringindexer", "Longitude_stringindexer", "Degrees_stringindexer", "Minutes_stringindexer", "Seconds_stringindexer", "Partition_stringindexer", "VerificationCount_stringindexer", "CreatedOn_dayofmonth", "CreatedOn_month", "CreatedOn_year"], "VerificationStatus_stringindexer")

	#mlPostExecutionHook(dataAutoML)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***PREDICT ON TRAINED MODEL***

# %%
import pandas as pd
import numpy as np
import sklearn.metrics

try:
    model=dataAutoML['model']
    X_test=dataAutoML['X_test']
    y_test=dataAutoML['y_test']
    label=dataAutoML['label']
    columnNames=dataAutoML['columnNames']
    if label in columnNames:
        columnNames.remove(label)
    predicted=label+"_predicted"
    y_predicted=model.predict(X_test)
    df =pd.DataFrame(X_test , columns=columnNames)
    df[label]=y_test
    df[predicted]=y_predicted
    columnNames.insert(0,predicted)
    columnNames.insert(0,label)
    Accuracy = np.round((100 * sklearn.metrics.accuracy_score(y_true=y_test, y_pred=y_predicted)), 1)
    F1= np.round(
            (100 * sklearn.metrics.f1_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    Precision= np.round((
                100 * sklearn.metrics.precision_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    Recall = np.round((
                100 * sklearn.metrics.recall_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    display(" Accuracy of Prediction on test data    : %s"%Accuracy)
    display(" F1 score of Prediction on test data    : %s"%F1)
    display(" Precision of Prediction on test data   : %s"%Precision)
    display(" Recall of Prediction on test data      : %s"%Recall)
    display(df.head())
except Exception as ex:
    logging.error(ex)
